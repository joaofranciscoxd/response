# %%
import requests
from bs4 import BeautifulSoup
from sqlalchemy import create_engine, Column, Integer, String, DateTime
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from sqlalchemy.orm import relationship
from sqlalchemy import ForeignKey
import os
import logging
from datetime import datetime

# %%
database_file = "wiki_data.db"
engine = create_engine(f"sqlite:///{database_file}")

# %%
import pandas as pd
from sqlalchemy import inspect

# Create the inspector
inspector = inspect(engine)

# Get the table names
table_names = inspector.get_table_names()

# %%
lista_dfs = []
# Iterate over the table names
for table_name in table_names:
    # Load the table content into a DataFrame
    df = pd.read_sql_table(table_name, engine)
    
    # Print the table name
    print(f"Table: {table_name}")
    
    lista_dfs.append(df)
# Out:
# Table: facts
# Table: featured_images
# Table: preview_links

# %%
i = 0
print(table_names[i])
lista_dfs[i]
# Out:
# facts
#    id                                            content  \
# 0   1  ... that before Major League Baseball pitcher ...
# 1   2  ... that Piri's self-produced music video for ...
# 2   3  ... that the 17-animal inheritance puzzle has ...
# 3   4  ... that Seda Kaçan became Turkey's first race...
# 4   5  ... that the Vegas Golden Knights used five di...
# 5   6  ... that Leonard Abrams founded the arts and c...
# 6   7  ... that though the Offerman Building is only ...
# 7   8  ... that John Oliver dared Disney to sue him o...
#
#                   created_at day_of_week  analyzed  \
# 0 2023-07-08 20:56:29.982419    Saturday      True
# 1 2023-07-08 20:56:29.986407    Saturday      True
# 2 2023-07-08 20:56:29.987694    Saturday      True
# 3 2023-07-08 20:56:29.988751    Saturday      True
# 4 2023-07-08 20:56:29.989820    Saturday      True
# 5 2023-07-08 20:56:29.990880    Saturday      True
# 6 2023-07-08 20:56:29.991941    Saturday      True
# 7 2023-07-08 20:56:29.993002    Saturday      True
#
#                                       internal_links  \
# 0  'https://en.wikipedia.org/wiki/2023', 'https:/...
# 1  'https://en.wikipedia.org/wiki/Bedroom', 'http...
# 2  'https://en.wikipedia.org/wiki/17', 'https://e...
# 3  'https://en.wikipedia.org/wiki/Driver', 'https...
# 4  'https://en.wikipedia.org/wiki/2022–23_UEFA_Ch...
# 5  'https://en.wikipedia.org/wiki/Abrams', 'https...
# 6  'https://en.wikipedia.org/wiki/Brooklyn', 'htt...
# 7  'https://en.wikipedia.org/wiki/Dare', 'https:/...
#
#             campaign_parameters
# 0  {'date': None, 'length': 28}
# 1                {'length': 25}
# 2                {'length': 18}
# 3                {'length': 10}
# 4                {'length': 18}
# 5                {'length': 27}
# 6                {'length': 24}
# 7                {'length': 15}

# %%
lista_dfs[i]['content'][0]
# Out:
# '... that before Major League Baseball pitcher Keaton Winn (pictured) was called up to the majors in June 2023, he had never been to a major league stadium?'

# %%
print(lista_dfs[i]['internal_links'][0][1:-1])
# Out:
# https://en.wikipedia.org/wiki/2023', 'https://en.wikipedia.org/wiki/2023_Cricket_World_Cup', "https://en.wikipedia.org/wiki/2023_FIFA_Women's_World_Cup", 'https://en.wikipedia.org/wiki/2023_NBA_draft', 'https://en.wikipedia.org/wiki/2023_Turkey–Syria_earthquake', 'https://en.wikipedia.org/wiki/Baseball', 'https://en.wikipedia.org/wiki/Major_League_Baseball', 'https://en.wikipedia.org/wiki/List_of_baseball_video_games', 'https://en.wikipedia.org/wiki/Triple-A_(baseball)', 'https://en.wikipedia.org/wiki/Perfect_game_(baseball)', 'https://en.wikipedia.org/wiki/Call', 'https://en.wikipedia.org/wiki/Computer-assisted_language_learning', 'https://en.wikipedia.org/wiki/On-call', 'https://en.wikipedia.org/wiki/The_Call', 'https://en.wikipedia.org/wiki/Call_of_Duty', 'https://en.wikipedia.org/wiki/June', 'https://en.wikipedia.org/wiki/June_30', 'https://en.wikipedia.org/wiki/June_26', 'https://en.wikipedia.org/wiki/June_25', 'https://en.wikipedia.org/wiki/June_29', 'https://en.wikipedia.org/wiki/Buster_Keaton', 'https://en.wikipedia.org/wiki/Diane_Keaton', 'https://en.wikipedia.org/wiki/Keaton', 'https://en.wikipedia.org/wiki/Michael_Keaton', 'https://en.wikipedia.org/wiki/Camille_Keaton', 'https://en.wikipedia.org/wiki/League', 'https://en.wikipedia.org/wiki/Premier_League', 'https://en.wikipedia.org/wiki/English_Football_League', 'https://en.wikipedia.org/wiki/UEFA_Champions_League', 'https://en.wikipedia.org/wiki/2023–24_UEFA_Champions_League', 'https://en.wikipedia.org/wiki/Major', 'https://en.wikipedia.org/wiki/Major_(disambiguation)', 'https://en.wikipedia.org/wiki/Major_Major_Major_Major', 'https://en.wikipedia.org/wiki/Major_Major', 'https://en.wikipedia.org/wiki/John_Major', 'https://en.wikipedia.org/wiki/Picture-in-picture', 'https://en.wikipedia.org/wiki/Image', 'https://en.wikipedia.org/wiki/COBOL', 'https://en.wikipedia.org/wiki/Film', 'https://en.wikipedia.org/wiki/Academy_Award_for_Best_Picture', 'https://en.wikipedia.org/wiki/Pitcher', 'https://en.wikipedia.org/wiki/Pitcher_plant', 'https://en.wikipedia.org/wiki/List_of_Major_League_Baseball_perfect_games', 'https://en.wikipedia.org/wiki/Win–loss_record_(pitching)', 'https://en.wikipedia.org/wiki/Relief_pitcher', 'https://en.wikipedia.org/wiki/Stadium', 'https://en.wikipedia.org/wiki/Wembley_Stadium', 'https://en.wikipedia.org/wiki/London_Stadium', 'https://en.wikipedia.org/wiki/Reputation_Stadium_Tour', 'https://en.wikipedia.org/wiki/Mikheil_Meskhi_Stadium', 'https://en.wikipedia.org/wiki/Winn', 'https://en.wikipedia.org/wiki/WINN', 'https://en.wikipedia.org/wiki/Raynor_Winn', 'https://en.wikipedia.org/wiki/Winn-Dixie', 'https://en.wikipedia.org/wiki/Keaton_Winn

# %%
lista_dfs[i]['campaign_parameters'][0]
# Out:
# "{'date': None, 'length': 28}"

# %%
i = 1
print(table_names[i])
lista_dfs[i]
# Out:
# featured_images
#    id                                          image_url      caption  fact_id
# 0   1  https://en.wikipedia.org/wiki/File:Win_profile...  Keaton Winn        1

# %%
i = 2
print(table_names[i])
lista_dfs[i]
# Out:
# preview_links
#     id                                                url  fact_id
# 0    1  https://en.wikipedia.org/wiki/Major_League_Bas...        1
# 1    2          https://en.wikipedia.org/wiki/Keaton_Winn        1
# 2    3                 https://en.wikipedia.org/wiki/Piri        2
# 3    4     https://en.wikipedia.org/wiki/Soft_Spot_(song)        2
# 4    5            https://en.wikipedia.org/wiki/Projector        2
# 5    6              https://en.wikipedia.org/wiki/YouTube        2
# 6    7  https://en.wikipedia.org/wiki/17-animal_inheri...        3
# 7    8      https://en.wikipedia.org/wiki/Seda_Ka%C3%A7an        4
# 8    9  https://en.wikipedia.org/wiki/Vegas_Golden_Kni...        5
# 9   10  https://en.wikipedia.org/wiki/2022%E2%80%9323_...        5
# 10  11          https://en.wikipedia.org/wiki/Stanley_Cup        5
# 11  12       https://en.wikipedia.org/wiki/Leonard_Abrams        6
# 12  13     https://en.wikipedia.org/wiki/East_Village_Eye        6
# 13  14        https://en.wikipedia.org/wiki/Hip_hop_music        6
# 14  15    https://en.wikipedia.org/wiki/Offerman_Building        7
# 15  16  https://en.wikipedia.org/wiki/List_of_tallest_...        7
# 16  17          https://en.wikipedia.org/wiki/John_Oliver        8
# 17  18  https://en.wikipedia.org/wiki/Mickey_Mouse_(La...        8

# %%
query = '''
    SELECT f.*, fi.*, GROUP_CONCAT(DISTINCT pl.id) AS pl_id,  GROUP_CONCAT(DISTINCT pl.url) AS preview_urls, pl.fact_id AS fact_id_2
    FROM facts f
    LEFT JOIN featured_images fi ON fi.fact_id = f.id
    LEFT JOIN preview_links pl ON pl.fact_id = f.id
    --WHERE f.id = 1
    GROUP BY f.id
    '''
query_df = pd.read_sql_query(query, engine)
query_df.columns = ['id', 'content', 'created_at', 'day_of_week', 'analyzed',
                    'internal_links', 'campaign_parameters', 'fi_id', 'image_url', 'caption',
                        'fact_id_1', 'pl_id', 'preview_urls', 'fact_id_2']
query_df
# Out:
#    id                                            content  \
# 0   1  ... that before Major League Baseball pitcher ...
# 1   2  ... that Piri's self-produced music video for ...
# 2   3  ... that the 17-animal inheritance puzzle has ...
# 3   4  ... that Seda Kaçan became Turkey's first race...
# 4   5  ... that the Vegas Golden Knights used five di...
# 5   6  ... that Leonard Abrams founded the arts and c...
# 6   7  ... that though the Offerman Building is only ...
# 7   8  ... that John Oliver dared Disney to sue him o...
#
#                    created_at day_of_week  analyzed  \
# 0  2023-07-08 20:56:29.982419    Saturday         1
# 1  2023-07-08 20:56:29.986407    Saturday         1
# 2  2023-07-08 20:56:29.987694    Saturday         1
# 3  2023-07-08 20:56:29.988751    Saturday         1
# 4  2023-07-08 20:56:29.989820    Saturday         1
# 5  2023-07-08 20:56:29.990880    Saturday         1
# 6  2023-07-08 20:56:29.991941    Saturday         1
# 7  2023-07-08 20:56:29.993002    Saturday         1
#
#                                       internal_links  \
# 0  'https://en.wikipedia.org/wiki/2023', 'https:/...
# 1  'https://en.wikipedia.org/wiki/Bedroom', 'http...
# 2  'https://en.wikipedia.org/wiki/17', 'https://e...
# 3  'https://en.wikipedia.org/wiki/Driver', 'https...
# 4  'https://en.wikipedia.org/wiki/2022–23_UEFA_Ch...
# 5  'https://en.wikipedia.org/wiki/Abrams', 'https...
# 6  'https://en.wikipedia.org/wiki/Brooklyn', 'htt...
# 7  'https://en.wikipedia.org/wiki/Dare', 'https:/...
#
#             campaign_parameters  fi_id  \
# 0  {'date': None, 'length': 28}    1.0
# 1                {'length': 25}    NaN
# 2                {'length': 18}    NaN
# 3                {'length': 10}    NaN
# 4                {'length': 18}    NaN
# 5                {'length': 27}    NaN
# 6                {'length': 24}    NaN
# 7                {'length': 15}    NaN
#
#                                            image_url      caption  fact_id_1  \
# 0  https://en.wikipedia.org/wiki/File:Win_profile...  Keaton Winn        1.0
# 1                                               None         None        NaN
# 2                                               None         None        NaN
# 3                                               None         None        NaN
# 4                                               None         None        NaN
# 5                                               None         None        NaN
# 6                                               None         None        NaN
# 7                                               None         None        NaN
#
#       pl_id                                       preview_urls  fact_id_2
# 0       2,1  https://en.wikipedia.org/wiki/Keaton_Winn,http...          1
# 1   3,5,4,6  https://en.wikipedia.org/wiki/Piri,https://en....          2
# 2         7  https://en.wikipedia.org/wiki/17-animal_inheri...          3
# 3         8      https://en.wikipedia.org/wiki/Seda_Ka%C3%A7an          4
# 4   10,11,9  https://en.wikipedia.org/wiki/2022%E2%80%9323_...          5
# 5  13,14,12  https://en.wikipedia.org/wiki/East_Village_Eye...          6
# 6     16,15  https://en.wikipedia.org/wiki/List_of_tallest_...          7
# 7     17,18  https://en.wikipedia.org/wiki/John_Oliver,http...          8

# %%
query_df
# Out:
#    id                                            content  \
# 0   1  ... that before Major League Baseball pitcher ...
# 1   2  ... that Piri's self-produced music video for ...
# 2   3  ... that the 17-animal inheritance puzzle has ...
# 3   4  ... that Seda Kaçan became Turkey's first race...
# 4   5  ... that the Vegas Golden Knights used five di...
# 5   6  ... that Leonard Abrams founded the arts and c...
# 6   7  ... that though the Offerman Building is only ...
# 7   8  ... that John Oliver dared Disney to sue him o...
#
#                    created_at day_of_week  analyzed  \
# 0  2023-07-08 20:56:29.982419    Saturday         1
# 1  2023-07-08 20:56:29.986407    Saturday         1
# 2  2023-07-08 20:56:29.987694    Saturday         1
# 3  2023-07-08 20:56:29.988751    Saturday         1
# 4  2023-07-08 20:56:29.989820    Saturday         1
# 5  2023-07-08 20:56:29.990880    Saturday         1
# 6  2023-07-08 20:56:29.991941    Saturday         1
# 7  2023-07-08 20:56:29.993002    Saturday         1
#
#                                       internal_links  \
# 0  'https://en.wikipedia.org/wiki/2023', 'https:/...
# 1  'https://en.wikipedia.org/wiki/Bedroom', 'http...
# 2  'https://en.wikipedia.org/wiki/17', 'https://e...
# 3  'https://en.wikipedia.org/wiki/Driver', 'https...
# 4  'https://en.wikipedia.org/wiki/2022–23_UEFA_Ch...
# 5  'https://en.wikipedia.org/wiki/Abrams', 'https...
# 6  'https://en.wikipedia.org/wiki/Brooklyn', 'htt...
# 7  'https://en.wikipedia.org/wiki/Dare', 'https:/...
#
#             campaign_parameters  fi_id  \
# 0  {'date': None, 'length': 28}    1.0
# 1                {'length': 25}    NaN
# 2                {'length': 18}    NaN
# 3                {'length': 10}    NaN
# 4                {'length': 18}    NaN
# 5                {'length': 27}    NaN
# 6                {'length': 24}    NaN
# 7                {'length': 15}    NaN
#
#                                            image_url      caption  fact_id_1  \
# 0  https://en.wikipedia.org/wiki/File:Win_profile...  Keaton Winn        1.0
# 1                                               None         None        NaN
# 2                                               None         None        NaN
# 3                                               None         None        NaN
# 4                                               None         None        NaN
# 5                                               None         None        NaN
# 6                                               None         None        NaN
# 7                                               None         None        NaN
#
#       pl_id                                       preview_urls  fact_id_2
# 0       2,1  https://en.wikipedia.org/wiki/Keaton_Winn,http...          1
# 1   3,5,4,6  https://en.wikipedia.org/wiki/Piri,https://en....          2
# 2         7  https://en.wikipedia.org/wiki/17-animal_inheri...          3
# 3         8      https://en.wikipedia.org/wiki/Seda_Ka%C3%A7an          4
# 4   10,11,9  https://en.wikipedia.org/wiki/2022%E2%80%9323_...          5
# 5  13,14,12  https://en.wikipedia.org/wiki/East_Village_Eye...          6
# 6     16,15  https://en.wikipedia.org/wiki/List_of_tallest_...          7
# 7     17,18  https://en.wikipedia.org/wiki/John_Oliver,http...          8

# %%
query_df[['pl_id','preview_urls','fact_id_2']]['preview_urls']
# Out:
# 0    https://en.wikipedia.org/wiki/Keaton_Winn,http...
# 1    https://en.wikipedia.org/wiki/Piri,https://en....
# 2    https://en.wikipedia.org/wiki/17-animal_inheri...
# 3        https://en.wikipedia.org/wiki/Seda_Ka%C3%A7an
# 4    https://en.wikipedia.org/wiki/2022%E2%80%9323_...
# 5    https://en.wikipedia.org/wiki/East_Village_Eye...
# 6    https://en.wikipedia.org/wiki/List_of_tallest_...
# 7    https://en.wikipedia.org/wiki/John_Oliver,http...
# Name: preview_urls, dtype: object

# %%
query_df[['pl_id','preview_urls','fact_id_2']]['preview_urls'][0].split(',')
# Out:
# ['https://en.wikipedia.org/wiki/Keaton_Winn',
#  'https://en.wikipedia.org/wiki/Major_League_Baseball']
